# %%
import os
from glob import glob
from pandas import DataFrame
import pandas as pd
import configparser
import subprocess as sp
import matplotlib.pyplot as plt
import pprint

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
bench_start = '2018-11-08_00:12:48'
bench_end = '2018-11-08_02:54:12'

experiments_path = '/home/dongwonshin/Desktop/SLAM_eval/Experiment_Results'
all_benchmarks = sorted(glob('%s/*' % experiments_path))

# benchmark filtereing
filtered_benchmarks = []
for benchmark in all_benchmarks:
    if (bench_start <= benchmark.split('/')[-1] and benchmark.split('/')[-1] <= bench_end):
        filtered_benchmarks.append(benchmark)

segmap_config_table = DataFrame()
for benchmark in filtered_benchmarks:
    config = configparser.ConfigParser()
    config.read(os.path.join(benchmark, 'POI.ini'))
    target_kitti_data = config.get('PARAMETERS','target_kitti_data')
    icp_config = config.get('PARAMETERS','icp_config')
    odom_config = config.get('PARAMETERS','odom_config')

    segmap_config_table = segmap_config_table.append({"benchmark_path": benchmark.split('/')[-1],
                                                      "target_kitti_data": target_kitti_data, 
                                                      "icp_config": icp_config, 
                                                      "odom_config" : odom_config}, ignore_index = True)

# for eval_type in ['ape', 'rpe']:
#     result_files = ""
#     for index, row in df.iterrows():
#         result_files += os.path.join('\"%s' % experiments_path ,row['benchmark_path'],'%s_eval/%s_results.zip\"' % (eval_type, eval_type)) + " "

#     os.system('evo_res %s --save_table %s_table.csv --use_filenames --no_warnings --silent' % (result_files, eval_type))

# %%
def constructe_table(table_file, df, target_kitti_data):
    print(table_file)
    table = pd.read_csv(table_file)
    for idx in range(len(df)):
        table.ix[:,0][idx] = table.ix[:,0][idx].split('/')[-3]

    table.columns = ['benchmark_path', 'max', 'mean', 'median', 'min', 'rmse', 'sse', 'std']
    table = pd.merge(table,df)

    # conditions
    table = table[
#         (table['target_kitti_data']==str(target_kitti_data))
        (table['odom_config']=='without_odom')
        & (table['icp_config']=='semantic_icp')
    ]
    return table

def bar_plot(title, table):
    table.ix[:,5].plot(kind = 'bar')
    plt.title(title)
    plt.show()

# %%
segmap_ape_table = constructe_table('/home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv', segmap_config_table, target_kitti_data)
# Out:
# /home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv

# %%
for target_kitti_data in [0,1,2,4,5,6,7,8,9,10]:
    print('target_kitti_data : %d' % target_kitti_data)
    segmap_ape_table = constructe_table('/home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv', segmap_config_table, target_kitti_data)
#     print(segmap_ape_table[['benchmark_path','rmse','icp_config','odom_config']])
#     bar_plot('segmap_ape_table',segmap_ape_table)
# Out:
# target_kitti_data : 0
# /home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv
# target_kitti_data : 1
# /home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv
# target_kitti_data : 2
# /home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv
# target_kitti_data : 4
# /home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-b2f67b244d92> in <module>()
#       1 for target_kitti_data in [0,1,2,4,5,6,7,8,9,10]:
#       2     print('target_kitti_data : %d' % target_kitti_data)
# ----> 3     segmap_ape_table = constructe_table('/home/dongwonshin/Desktop/SLAM_eval/Research_Notes/segmap_results/ape_table.csv', segmap_config_table, target_kitti_data)
#       4 #     print(segmap_ape_table[['benchmark_path','rmse','icp_config','odom_config']])
#       5 #     bar_plot('segmap_ape_table',segmap_ape_table)
#
# <ipython-input-52-3a8c476a7d04> in constructe_table(table_file, df, target_kitti_data)
#       3     table = pd.read_csv(table_file)
#       4     for idx in range(len(df)):
# ----> 5         table.ix[:,0][idx] = table.ix[:,0][idx].split('/')[-3]
#       6
#       7     table.columns = ['benchmark_path', 'max', 'mean', 'median', 'min', 'rmse', 'sse', 'std']
#
# ~/anaconda3/envs/segmappy/lib/python3.5/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     936
#     937         # do the setitem
# --> 938         cacher_needs_updating = self._check_is_chained_assignment_possible()
#     939         setitem(key, value)
#     940         if cacher_needs_updating:
#
# ~/anaconda3/envs/segmappy/lib/python3.5/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    2625             if ref is not None and ref._is_mixed_type:
#    2626                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 2627                                          force=True)
#    2628             return True
#    2629         elif self._is_copy:
#
# ~/anaconda3/envs/segmappy/lib/python3.5/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    2671             # the copy weakref
#    2672             try:
# -> 2673                 gc.collect(2)
#    2674                 if not gc.get_referents(self._is_copy()):
#    2675                     self._is_copy = None
#
# KeyboardInterrupt:

# %%
bench_start = '2018-11-20_23:17:44'
bench_end = '2018-11-21_01:26:28'

experiments_path = '/home/dongwonshin/Desktop/ORB_SLAM2/Benchmark/results'
all_benchmarks = sorted(glob('%s/*' % experiments_path))

# benchmark filtereing
filtered_benchmarks = []
for benchmark in all_benchmarks:
    if (bench_start <= benchmark.split('/')[-1] and benchmark.split('/')[-1] <= bench_end):
        filtered_benchmarks.append(benchmark)
        
orbslam_config_table = DataFrame()
for benchmark in filtered_benchmarks:
    config = configparser.ConfigParser()
    config.read(os.path.join(benchmark, 'POI.ini'))
    target_kitti_data = config.get('PARAMETERS','target_kitti_data')
    algorithm = config.get('PARAMETERS','algorithm')

    orbslam_config_table = orbslam_config_table.append({"benchmark_path": benchmark.split('/')[-1],
                                        "target_kitti_data": target_kitti_data, 
                                        "algorithm": algorithm}, ignore_index = True)

# for eval_type in ['ape', 'rpe']:
#     result_files = ""
#     for index, row in df.iterrows():
#         result_files += os.path.join('\"%s' % experiments_path ,row['benchmark_path'],'%s_eval/%s_results.zip\"' % (eval_type, eval_type)) + " "
    
#     os.system('evo_res %s --save_table %s_table.csv --use_filenames --no_warnings --silent' % (result_files, eval_type))

# %%
orbslam_ape_table_file = '/home/dongwonshin/Desktop/SLAM_eval/Research_Notes/orbslam2_results/ape_table.csv'
orbslam_ape_table = pd.read_csv(ape_table_file)
for idx in range(len(orbslam_config_table)):
    orbslam_ape_table.ix[:,0][idx] = orbslam_ape_table.ix[:,0][idx].split('/')[-3]

orbslam_ape_table.columns = ['benchmark_path', 'max', 'mean', 'median', 'min', 'rmse', 'sse', 'std']
orbslam_ape_table = pd.merge(orbslam_ape_table,orbslam_config_table)

# # conditions
# table = table[
#     (table['target_kitti_data']==str(target_kitti_data))
#     & (table['odom_config']=='without_odom')
# #         & (table['icp_config']=='semantic_icp')
# ]
# return table

# %%
orbslam_ape_table
# Out:
#          benchmark_path         max        mean      median       min  \
# 0   2018-11-20_23:17:44   14.258415    6.031193    4.578139  0.502160
# 1   2018-11-20_23:19:51  981.816779  456.287936  504.910539  8.166438
# 2   2018-11-20_23:28:22   85.964126   17.932635   10.639873  0.866894
# 3   2018-11-20_23:29:58    4.583076    1.051396    0.835216  0.172940
# 4   2018-11-20_23:30:36    1.071452    0.356231    0.294794  0.076810
# 5   2018-11-20_23:35:43    8.595259    4.846616    5.243289  0.383608
# 6   2018-11-20_23:37:51   24.445284   12.156518   12.896560  0.434791
# 7   2018-11-20_23:39:58    5.541099    2.860496    2.747243  0.103417
# 8   2018-11-20_23:47:24  149.049276   42.396222   31.784986  1.053263
# 9   2018-11-20_23:50:24   81.881780   16.301563   12.976469  2.501489
# 10  2018-11-20_23:52:42   23.900764    5.753692    4.115836  0.905251
# 11  2018-11-21_00:50:12    2.724457    0.956111    0.921332  0.024558
# 12  2018-11-21_00:52:28    8.120206    3.204003    3.104715  0.824186
# 13  2018-11-21_01:01:16   12.881776    4.592026    3.904836  0.729241
# 14  2018-11-21_01:02:56    0.501814    0.272043    0.261892  0.028332
# 15  2018-11-21_01:03:35    0.383909    0.193014    0.196395  0.032495
# 16  2018-11-21_01:08:52    1.100216    0.348729    0.316057  0.030639
# 17  2018-11-21_01:11:04    1.101768    0.730797    0.868357  0.062813
# 18  2018-11-21_01:13:16    0.783428    0.449173    0.426877  0.132429
# 19  2018-11-21_01:20:58    9.902496    2.738264    2.204188  0.231449
# 20  2018-11-21_01:24:05    6.908087    2.271418    1.418160  0.439142
# 21  2018-11-21_01:26:28    2.688417    0.929818    0.796615  0.231095
#
#           rmse           sse         std           algorithm target_kitti_data
# 0     7.097950  8.584904e+04    3.742406  orbslam2 Monocular                 0
# 1   535.067874  1.050712e+08  279.461893  orbslam2 Monocular                 1
# 2    24.756900  1.388228e+06   17.068237  orbslam2 Monocular                 2
# 3     1.301378  5.250113e+02    0.766911  orbslam2 Monocular                 3
# 4     0.408041  2.131163e+01    0.198988  orbslam2 Monocular                 4
# 5     5.130632  2.740264e+04    1.683359  orbslam2 Monocular                 5
# 6    14.085987  8.690578e+04    7.115764  orbslam2 Monocular                 6
# 7     3.078574  4.075374e+03    1.138058  orbslam2 Monocular                 7
# 8    53.360824  5.449881e+06   32.402745  orbslam2 Monocular                 8
# 9    21.710903  2.875316e+05   14.339538  orbslam2 Monocular                 9
# 10    7.493413  2.992861e+04    4.800654  orbslam2 Monocular                10
# 11    1.023244  4.754554e+03    0.364527     orbslam2 Stereo                 0
# 12    3.494313  1.344346e+04    1.394485     orbslam2 Stereo                 1
# 13    5.520282  1.420371e+05    3.063790     orbslam2 Stereo                 2
# 14    0.294193  6.932604e+01    0.111992     orbslam2 Stereo                 3
# 15    0.213094  1.230583e+01    0.090302     orbslam2 Stereo                 4
# 16    0.398239  4.378784e+02    0.192308     orbslam2 Stereo                 5
# 17    0.792561  6.915972e+02    0.306740     orbslam2 Stereo                 6
# 18    0.485067  2.590543e+02    0.183121     orbslam2 Stereo                 7
# 19    3.307197  4.452678e+04    1.854579     orbslam2 Stereo                 8
# 20    2.852231  1.294314e+04    1.725075     orbslam2 Stereo                 9
# 21    1.052709  1.330944e+03    0.493594     orbslam2 Stereo                10

# %%
segmap_ape_table
# Out:
#          benchmark_path         max        mean      median        min  \
# 1   2018-11-08_00:20:49  270.361311   52.660248   33.609204   6.665165
# 5   2018-11-08_00:41:05  226.284526  150.379520  161.137175  23.966663
# 9   2018-11-08_01:01:45   93.006223   22.757883   18.144715   4.707821
# 13  2018-11-08_01:19:21   24.186344    9.362879    6.056325   0.462432
# 17  2018-11-08_01:30:19   20.697316   12.532035   13.536148   1.313781
# 21  2018-11-08_01:44:10   33.323491   20.110133   19.332452   4.092969
# 25  2018-11-08_01:52:25   23.572855    9.938172    9.757121   1.358286
# 29  2018-11-08_02:14:57  155.748344   76.615826   80.585119   8.466097
# 33  2018-11-08_02:38:52   91.671407   31.875564   20.978039   0.922980
# 37  2018-11-08_02:49:30   22.827270    8.063537    6.969909   0.497764
#
#           rmse           sse        std    icp_config   odom_config  \
# 1    78.990118  2.556922e+07  58.875607  semantic_icp  without_odom
# 5   157.045701  2.624181e+07  45.269772  semantic_icp  without_odom
# 9    27.338854  3.310292e+06  15.148984  semantic_icp  without_odom
# 13   11.555941  3.071415e+04   6.773202  semantic_icp  without_odom
# 17   13.239604  4.534678e+05   4.270272  semantic_icp  without_odom
# 21   21.458035  4.645913e+05   7.485307  semantic_icp  without_odom
# 25   11.086769  1.252519e+05   4.914183  semantic_icp  without_odom
# 29   86.043054  3.983033e+06  39.158937  semantic_icp  without_odom
# 33   40.586615  2.470910e+06  25.124126  semantic_icp  without_odom
# 37    9.563981  1.086660e+05   5.142869  semantic_icp  without_odom
#
#    target_kitti_data
# 1                  0
# 5                  1
# 9                  2
# 13                 4
# 17                 5
# 21                 6
# 25                 7
# 29                 8
# 33                 9
# 37                10
